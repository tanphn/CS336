# %%
# !pip install pyngrok
# !pip install -q streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 94.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 110.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.5 MB/s eta 0:00:00

# %%
# !pip install sentence-transformers

# %%
from pyngrok import ngrok
#ngrok.set_auth_token("2qwbXFOAYr9jNjFsaSmpKIKJpHR_69p28XcgdwTp8L3JkP6iy")  # Thay YOUR_AUTH_TOKEN bằng token của bạn
ngrok.set_auth_token("2r4kqy4fAMQlapEmxtTxzB9E6gC_6RcKBhrTVVC3eugRk6jZL")

# %%
import torch
if torch.cuda.is_available():
    print("CUDA is available. Installing qdrant-client with fastembed-gpu support.")
    # %pip install 'qdrant-client[fastembed-gpu]'
    have_cuda = True
else:
    print("CUDA is not available. Installing qdrant-client with fastembed (CPU-only) support.")
    # %pip install 'qdrant-client[fastembed]'
    have_cuda = False
# Out:
# CUDA is available. Installing qdrant-client with fastembed-gpu support.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 95.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 80.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.9/323.9 kB 27.9 MB/s eta 0:00:00
# ...

# %%
# Uncomment to use not use fastembed
# %pip install -U llama-index
# %pip install -U qdrant-client
# !pip install -U "huggingface_hub[cli]"
# !huggingface-cli login --token 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
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.3/454.3 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.4
#     Uninstalling openai-1.57.4:
#       Successfully uninstalled openai-1.57.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.1 MB/s eta 0:00:00
# ...
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/BKAI_2/check_point_model/fintune_lan_3/jin-AI.zip
# Out:
# Archive:  /content/drive/MyDrive/BKAI_2/check_point_model/fintune_lan_3/jin-AI.zip
#   inflating: jin-AI/checkpoint-68400/config_sentence_transformers.json
#   inflating: jin-AI/checkpoint-68400/config.json
#   inflating: jin-AI/checkpoint-68400/model.safetensors
#   inflating: jin-AI/checkpoint-68400/tokenizer_config.json
#   inflating: jin-AI/checkpoint-68400/special_tokens_map.json
#   inflating: jin-AI/checkpoint-68400/tokenizer.json
#   inflating: jin-AI/checkpoint-68400/sentence_bert_config.json
#   inflating: jin-AI/checkpoint-68400/custom_st.py
#   inflating: jin-AI/checkpoint-68400/modules.json
#   inflating: jin-AI/checkpoint-68400/README.md
#   inflating: jin-AI/checkpoint-68400/training_args.bin
#   inflating: jin-AI/checkpoint-68400/optimizer.pt
#   inflating: jin-AI/checkpoint-68400/scheduler.pt
#   inflating: jin-AI/checkpoint-68400/rng_state.pth
#   inflating: jin-AI/checkpoint-68400/trainer_state.json
#   inflating: jin-AI/checkpoint-68400/1_Pooling/config.json
# ...

# %%
public_url = ngrok.connect(8501)
print("Streamlit URL:", public_url)
# !streamlit run query.py --server.port 8501
# Out:
# Streamlit URL: NgrokTunnel: "https://2aed-34-143-215-239.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.143.215.239:8501
#
# 2025-01-02 15:18:11.365 Uncaught exception GET /_stcore/stream (127.0.0.1)
# HTTPServerRequest(protocol='http', host='2aed-34-143-215-239.ngrok-free.app', method='GET', uri='/_stcore/stream', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tornado/websocket.py", line 937, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/web/server/browser_websocket_handler.py", line 126, in open
#     self._session_id = self._runtime.connect_session(
# ...
